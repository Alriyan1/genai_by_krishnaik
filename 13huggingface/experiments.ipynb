# %%
import os
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from langchain.llms import HuggingFaceHub

# %%
repo_id='mistralai/Mistral-7B-Instruct-v0.3'
llm = HuggingFaceEndpoint(
    repo_id=repo_id,
    max_new_tokens=150,
    temperature=0.7,
    huggingfacehub_api_token='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',
)
llm=ChatHuggingFace(llm=llm)

# %%
llm.invoke('what is YOLO main component')
# Out:
# AIMessage(content='The main component of YOLO (You Only Look Once) is the convolutional neural network (CNN). It consists of layers such as the input layer, convolution layers, pooling layers, fully connected layers, and the output layer. The unique aspect of YOLO is that it attempts to localize and classify objects in an image simultaneously in a single convolutional network, which makes it faster than other object detection systems.\n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 33, 'total_tokens': 130}, 'model_name': 'mistralai/Mistral-7B-Instruct-v0.3', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None}, id='run--c2ef5725-8af4-4cfe-810b-7d01bedb379f-0', usage_metadata={'input_tokens': 33, 'output_tokens': 97, 'total_tokens': 130})

# %%
from langchain import PromptTemplate,LLMChain
template="""
questions:{question}
answer: Lets think step by step
"""
prompt=PromptTemplate(template=template,input_variables=['question'])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template='\nquestions:{question}\nanswer: Lets think step by step\n'

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
llm.invoke('who won the recent cricket world cup')
# Out:
# AIMessage(content='The recent cricket world cup was won by Australia.\n', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 34, 'total_tokens': 52}, 'model_name': 'mistralai/Mistral-7B-Instruct-v0.3', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None}, id='run--ad1eda28-4823-4c4d-9338-1ef9b0cb584c-0', usage_metadata={'input_tokens': 34, 'output_tokens': 18, 'total_tokens': 52})

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
model=HuggingFaceEmbeddings(model="sentence-transformers/all-mpnet-base-v2")
embedding=model.embed_query('hi this is alriyan')

# %%
embedding
# Out:
# [0.054836779832839966,
#  0.010036733001470566,
#  -0.013201254419982433,
#  0.05227142199873924,
#  0.03175897151231766,
#  0.005328275263309479,
#  0.06642162799835205,
#  -0.03626050055027008,
#  -0.011945025064051151,
#  -0.00797340739518404,
#  -0.028469620272517204,
#  -0.06599371880292892,
#  -7.117733912309632e-05,
#  0.023015091195702553,
#  0.042769648134708405,
#  -0.012864768505096436,
#  0.008780665695667267,
#  0.005634000990539789,
#  0.06378970295190811,
#  0.006768451537936926,
#  0.020421775057911873,
#  0.04925503954291344,
#  -0.0354510098695755,
#  0.048626501113176346,
#  -0.013730796985328197,
#  -0.009906538762152195,
#  0.007216155994683504,
#  0.011344736441969872,
#  0.011806516908109188,
#  0.0663507878780365,
#  0.04312293604016304,
#  -0.05610698089003563,
#  -0.007971254177391529,
#  0.01161186769604683,
#  2.0308723378548166e-06,
#  -0.029425082728266716,
#  0.026552442461252213,
#  0.005821790546178818,
#  -0.06138730049133301,
# ...
